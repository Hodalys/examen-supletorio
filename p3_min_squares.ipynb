# %%
import numpy as np

def der_parcial_1_exp(xs: list, ys: list) -> tuple[float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro b al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * b + c_0 * A = c_ind

    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro b.

    ``c_0``: coeficiente del parámetro A.

    ``c_ind``: coeficiente del término independiente.

    """
    ln_ys = np.log(ys)
    c_1 = sum(xi**2 for xi in xs)
    c_0 = sum(xs)
    c_ind = sum(xi * ln_ys[i] for i, xi in enumerate(xs))
    return (c_1, c_0, c_ind)

def der_parcial_0_exp(xs: list, ys: list) -> tuple[float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro A al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * b + c_0 * A = c_ind

    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro b.

    ``c_0``: coeficiente del parámetro A.

    ``c_ind``: coeficiente del término independiente.

    """
    ln_ys = np.log(ys)
    c_1 = sum(xs)
    c_0 = len(xs)
    c_ind = sum(ln_ys)
    return (c_1, c_0, c_ind)

# %%
puntos_dados = [
    (-7.0, -2.48), (-6.95, 5.21), (-6.91, 5.79), (-6.87, 7.32), (-6.83, 0.13), (-6.79, 7.58), (-6.75, 3.38), (-6.71, 3.44), 
    (-6.67, -4.62), (-6.63, -0.14), (-6.59, 4.26), (-6.55, 2.5), (-6.51, 3.3), (-6.47, 1.35), (-6.43, 3.87), (-6.39, -2.44), 
    (-6.35, 2.17), (-6.31, 1.45), (-6.27, 0.82), (-6.23, 3.9), (-6.19, 2.21), (-6.15, 6.16), (-6.11, 4.64), (-6.07, 0.66), 
    (-6.03, -1.46), (-5.99, 3.3), (-5.95, 0.65), (-5.91, 5.65), (-5.87, 9.45), (-5.83, -2.37), (-5.79, 1.8), (-5.75, 1.8), 
    (-5.71, 6.72), (-5.67, -1.53), (-5.63, 9.06), (-5.59, 0.53), (-5.55, -5.18), (-5.51, 3.49), (-5.47, 7.74), (-5.43, 4.23), 
    (-5.39, 2.7), (-5.35, 2.96), (-5.31, 1.15), (-5.27, 4.79), (-5.23, 2.5), (-5.19, 0.83), (-5.15, -6.04), (-5.11, -6.16), 
    (-5.07, -2.36), (-5.03, -2.23), (-4.98, -0.9), (-4.94, 2.89), (-4.9, -2.34), (-4.86, 0.3), (-4.82, -2.89), (-4.78, 0.66), 
    (-4.74, 1.0), (-4.7, 5.26), (-4.66, -0.96), (-4.62, 0.72), (-4.58, 6.62), (-4.54, 3.97), (-4.5, -1.09), (-4.46, 6.13), 
    (-4.42, 4.12), (-4.38, 6.75), (-4.34, 9.89), (-4.3, 6.8), (-4.26, 3.55), (-4.22, 1.62), (-4.18, 2.22), (-4.14, 4.67), 
    (-4.1, 3.87), (-4.06, -0.6), (-4.02, 0.07), (-3.98, 1.0), (-3.94, 2.38), (-3.9, 9.58), (-3.86, 5.06), (-3.82, -1.58), 
    (-3.78, 4.79), (-3.74, 0.26), (-3.7, 10.75), (-3.66, 6.23), (-3.62, 4.65), (-3.58, 1.59), (-3.54, 6.79), (-3.5, 8.71), 
    (-3.46, 2.85), (-3.42, 7.05), (-3.38, 7.83), (-3.34, 4.57), (-3.3, 5.43), (-3.26, 2.97), (-3.22, 2.61), (-3.18, 2.28), 
    (-3.14, 7.98), (-3.1, 10.59), (-3.06, 9.46), (-3.02, 6.12), (-2.97, 3.57), (-2.93, 11.94), (-2.89, 8.14), (-2.85, 12.12), 
    (-2.81, 9.21), (-2.77, 9.43), (-2.73, 9.97), (-2.69, 8.24), (-2.65, 7.33), (-2.61, 7.23), (-2.57, 12.07), (-2.53, 9.58), 
    (-2.49, 12.35), (-2.45, 12.03), (-2.41, 7.5), (-2.37, 14.97), (-2.33, 8.77), (-2.29, 3.7), (-2.25, 6.82), (-2.21, 11.47), 
    (-2.17, 11.9), (-2.13, 11.18), (-2.09, 14.01), (-2.05, 12.55), (-2.01, 18.89), (-1.97, 13.24), (-1.93, 10.52), (-1.89, 6.87), 
    (-1.85, 14.16), (-1.81, 16.5), (-1.77, 14.6), (-1.73, 11.18), (-1.69, 11.64), (-1.65, 18.63), (-1.61, 19.29), (-1.57, 19.24), 
    (-1.53, 16.48), (-1.49, 15.7), (-1.45, 13.1), (-1.41, 14.45), (-1.37, 13.84), (-1.33, 16.02), (-1.29, 17.87), (-1.25, 27.07), 
    (-1.21, 24.01), (-1.17, 22.61), (-1.13, 24.49), (-1.09, 21.74), (-1.05, 19.06), (-1.01, 15.34), (-0.96, 19.73), (-0.92, 17.71), 
    (-0.88, 23.67), (-0.84, 16.43), (-0.8, 21.77), (-0.76, 18.92), (-0.72, 32.27), (-0.68, 19.22), (-0.64, 26.76), (-0.6, 22.83), 
    (-0.56, 23.2), (-0.52, 25.89), (-0.48, 23.29), (-0.44, 30.18), (-0.4, 28.02), (-0.36, 24.06), (-0.32, 24.59), (-0.28, 23.46), 
    (-0.24, 31.07), (-0.2, 31.56), (-0.16, 27.0), (-0.12, 31.62), (-0.08, 35.5), (-0.04, 32.82), (-0.0, 28.65), (0.03, 36.6), 
    (0.07, 33.92), (0.11, 35.97), (0.15, 30.86), (0.19, 31.47), (0.23, 38.52), (0.27, 32.5), (0.31, 36.67), (0.35, 31.59), 
    (0.39, 43.82), (0.43, 37.48), (0.47, 34.57), (0.51, 33.19), (0.55, 37.98), (0.59, 42.94), (0.63, 37.8), (0.67, 43.53), 
    (0.71, 34.77), (0.75, 33.96), (0.79, 34.17), (0.83, 40.71), (0.87, 40.09), (0.91, 45.15), (0.95, 46.26), (1.0, 40.69)
]

xs = [punto[0] for punto in puntos_dados]
ys = [punto[1] for punto in puntos_dados]
print(xs)
print(ys)
# Out:
# [-7.0, -6.95, -6.91, -6.87, -6.83, -6.79, -6.75, -6.71, -6.67, -6.63, -6.59, -6.55, -6.51, -6.47, -6.43, -6.39, -6.35, -6.31, -6.27, -6.23, -6.19, -6.15, -6.11, -6.07, -6.03, -5.99, -5.95, -5.91, -5.87, -5.83, -5.79, -5.75, -5.71, -5.67, -5.63, -5.59, -5.55, -5.51, -5.47, -5.43, -5.39, -5.35, -5.31, -5.27, -5.23, -5.19, -5.15, -5.11, -5.07, -5.03, -4.98, -4.94, -4.9, -4.86, -4.82, -4.78, -4.74, -4.7, -4.66, -4.62, -4.58, -4.54, -4.5, -4.46, -4.42, -4.38, -4.34, -4.3, -4.26, -4.22, -4.18, -4.14, -4.1, -4.06, -4.02, -3.98, -3.94, -3.9, -3.86, -3.82, -3.78, -3.74, -3.7, -3.66, -3.62, -3.58, -3.54, -3.5, -3.46, -3.42, -3.38, -3.34, -3.3, -3.26, -3.22, -3.18, -3.14, -3.1, -3.06, -3.02, -2.97, -2.93, -2.89, -2.85, -2.81, -2.77, -2.73, -2.69, -2.65, -2.61, -2.57, -2.53, -2.49, -2.45, -2.41, -2.37, -2.33, -2.29, -2.25, -2.21, -2.17, -2.13, -2.09, -2.05, -2.01, -1.97, -1.93, -1.89, -1.85, -1.81, -1.77, -1.73, -1.69, -1.65, -1.61, -1.57, -1.53, -1.49, -1.45, -1.41, -1.37, -1.33, -1.29, -1.25, 
# ...

# %%
import matplotlib.pyplot as plt

# Crear la gráfica
plt.figure(figsize=(8, 4))
plt.scatter(xs, ys, color='blue', label='Puntos')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfica de los puntos')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from src import ajustar_min_cuadrados
# UTILICE:
# ajustar_min_cuadrados()

# Calcular los parámetros A y b para la función y = Ae^(bx)
b, ln_A = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0_exp, der_parcial_1_exp])
A = np.exp(ln_A)

# Crear puntos para la curva de ajuste
x_curve = np.linspace(min(xs), max(xs), 100)
y_curve = A * np.exp(b * x_curve)

# Crear la gráfica
plt.figure(figsize=(8, 4))

# Graficar los puntos originales
plt.scatter(xs, ys, color='blue', alpha=0.5, label='Datos')

# Graficar la curva de ajuste
plt.plot(x_curve, y_curve, color='red', linewidth=2, 
         label=f'y = {A:.2f}e^({b:.2f}x)')

# Etiquetas de los ejes y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Ajuste por mínimos cuadrados')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [02-20 13:49:53][INFO] Se ajustarán 2 parámetros.
# [02-20 13:49:53][INFO]
# [[-599.25        200.                   nan]
#  [   0.          358.80500209           nan]]
# C:\Users\Hodalys\AppData\Local\Temp\ipykernel_11172\462479222.py:47: RuntimeWarning: invalid value encountered in log
#   ln_ys = np.log(ys)
# C:\Users\Hodalys\AppData\Local\Temp\ipykernel_11172\462479222.py:22: RuntimeWarning: invalid value encountered in log
#   ln_ys = np.log(ys)
